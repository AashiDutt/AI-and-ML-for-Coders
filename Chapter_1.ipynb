# %% [markdown]
# <a href="https://colab.research.google.com/github/AashiDutt/AI-and-ML-for-Coders/blob/main/Chapter_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import --> Define  --> Compile --> fit --> Predict

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.7.0

# %% [markdown]
# X = –1, 0, 1, 2, 3, 4
#
# Y = –3, –1, 1, 3, 5, 7
#
# We need to find relation/rules between X and Y

# %%
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

model = Sequential([Dense(units = 1, input_shape = [1])])
model.compile(optimizer = 'sgd', loss = 'mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype = float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype = float)

model.fit(xs,ys, epochs = 500)
print(model.predict([10.0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 466ms/step - loss: 0.9502
# Epoch 2/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.8734
# Epoch 3/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.8104
# Epoch 4/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7583
# Epoch 5/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7148
# Epoch 6/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6782
# Epoch 7/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6470
# Epoch 8/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6201
# Epoch 9/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5967
# Epoch 10/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5760
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5576
# Epoch 12/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5409
# ...

# %% [markdown]
# Predicted output is not exactly 19 because of 2 reasons:
#
# 1. Data used for training is very less.
# 2. The output is depicted from the probability of the model i.w it cannot be 100%. thus the output is never exact.

# %%
d1 = Dense(units= 1, input_shape=[1])
model = Sequential(d1)
model.compile(optimizer = 'sgd', loss = 'mean_squared_error')
model.fit(xs, ys, epochs = 500)
print(model.predict([10.0]))
print("Here is what i learned: {}".format(d1.get_weights()))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 232ms/step - loss: 12.8071
# Epoch 2/500
# 1/1 [==============================] - 0s 4ms/step - loss: 10.3038
# Epoch 3/500
# 1/1 [==============================] - 0s 8ms/step - loss: 8.3297
# Epoch 4/500
# 1/1 [==============================] - 0s 10ms/step - loss: 6.7720
# Epoch 5/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.5419
# Epoch 6/500
# 1/1 [==============================] - 0s 4ms/step - loss: 4.5698
# Epoch 7/500
# 1/1 [==============================] - 0s 5ms/step - loss: 3.8007
# Epoch 8/500
# 1/1 [==============================] - 0s 10ms/step - loss: 3.1913
# Epoch 9/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.7078
# Epoch 10/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.3233
# Epoch 11/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.0169
# Epoch 12/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.7719
# ...

# %% [markdown]
# Model learned ->  Y = 2X -1

# %%
import tensorflow as tf
import numpy as np

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense


X = [-1, 3, 2, 7, 5]
Y = [1, 13, 10, 25, 19]
d1 = Dense(units = 1, input_shape = [1])
model = Sequential(d1)
model.compile(optimizer = "sgd", loss = "mean_squared_error")

xs = np.array([-1.0, 3.0, 2.0, 7.0, 5.0], dtype = float)
ys = np.array([1.0, 13.0, 10.0, 25.0, 19.0], dtype = float)

model.fit(xs, ys,epochs = 500)
print(model.predict([10.0]))
print("Model learned: {}".format(d1.get_weights()))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 239ms/step - loss: 373.9387
# Epoch 2/500
# 1/1 [==============================] - 0s 7ms/step - loss: 153.7438
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 64.6112
# Epoch 4/500
# 1/1 [==============================] - 0s 6ms/step - loss: 28.5085
# Epoch 5/500
# 1/1 [==============================] - 0s 6ms/step - loss: 13.8629
# Epoch 6/500
# 1/1 [==============================] - 0s 6ms/step - loss: 7.8996
# Epoch 7/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.4498
# Epoch 8/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.4224
# Epoch 9/500
# 1/1 [==============================] - 0s 10ms/step - loss: 3.9709
# Epoch 10/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.7531
# Epoch 11/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.6303
# Epoch 12/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.5467
# ...

# %%
Y = 3X + 4
